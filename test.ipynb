# %%
# Set your PDF path here
from enhanced_pdf_extractor import process_pdf_enhanced
pdf_path = 'app//input//file05.pdf'  # Change to your PDF file

process_pdf_enhanced(pdf_path)
# Out:
# {'title': '----------------',
#  'outline': [{'level': 'H1', 'text': 'HOPE', 'page': 1},
#   {'level': 'H1', 'text': 'SEE', 'page': 1},
#   {'level': 'H1', 'text': 'HERE', 'page': 1},
#   {'level': 'H2', 'text': 'WWW.TOPJUMP.COM', 'page': 1}]}
